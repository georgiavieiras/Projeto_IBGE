-- %%
--Criando catalog
CREATE CATALOG IF NOT EXISTS ibge comment 'Catalog IBGE - Projeto ELT';
CREATE SCHEMA IF NOT EXISTS ibge.bronze COMMENT 'Camada Bronze - Dados Raw'

-- %%
--Criando volume
CREATE VOLUME IF NOT EXISTS ibge.bronze.vol_ingestion COMMENT 'Volume Ingestion - Arquivos Raw de Ingestão'
